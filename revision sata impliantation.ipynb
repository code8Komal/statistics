# %%
data=[2,32,45,63,98.,89]

# %%
data
# Out:
# [2, 32, 45, 63, 98.0, 89]

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df1=sns.load_dataset('titanic')

# %%
df1.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
data
# Out:
# [2, 32, 45, 63, 98.0, 89]

# %%
np.mean(data)
# Out:
# 54.833333333333336

# %%
data
# Out:
# [2, 32, 45, 63, 98.0, 89]

# %%
data.sort()

# %%
data
# Out:
# [2, 32, 45, 63, 89, 98.0]

# %%
np.median(data)
# Out:
# 54.0

# %%
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df1['age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
np.mean(df1['age'])
# Out:
# 29.69911764705882

# %%
data=[2, 32, 45, 63, 89, 98.0,101,2,2,32]

# %%
import statistics 
statistics.mode(data)
# Out:
# 2

# %%
df1.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data
# Out:
# [2, 32, 45, 63, 89, 98.0, 101, 2, 2, 32]

# %%
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df2=df1.copy

# %%
data
# Out:
# [2, 32, 45, 63, 89, 98.0, 101, 2, 2, 32]

# %%
print('the mean of data is',np.mean(data))
print('the median of data is ',np.median(data))
# Out:
# the mean of data is 46.6
# the median of data is  38.5

# %%
data.append(1000)

# %%
data
# Out:
# [2, 32, 45, 63, 89, 98.0, 101, 2, 2, 32, 1000]

# %%
print('the mean of data is',np.mean(data))
print('the median of data is ',np.median(data))
# Out:
# the mean of data is 133.27272727272728
# the median of data is  45.0

# %%
np.percentile(data,[25])
# Out:
# array([17.])

# %%
data
# Out:
# [2, 32, 45, 63, 89, 98.0, 101, 2, 2, 32, 1000]

# %%
np.percentile(data,[25,50,75,100])
# Out:
# array([  17. ,   45. ,   93.5, 1000. ])

# %%
data.append(200)
data.append(-300)
data.append(900)

# %%
data
# Out:
# [2, 32, 45, 63, 89, 98.0, 101, 2, 2, 32, 1000, 200, -300, 900]

# %%
sns.boxplot(data)
# Out:
# <AxesSubplot: >

# %%
sns.boxplot(data)
# Out:
# <AxesSubplot: >

# %%
sns.boxplot(data)
# Out:
# <AxesSubplot: >

# %%
data=[2, 32, 45, 63, 89, 98, 101, 2, 2, 32]

# %%
data
# Out:
# [2, 32, 45, 63, 89, 98, 101, 2, 2, 32]

# %%
np.var(data)
# Out:
# 1406.44

# %%
np.std(data)
# Out:
# 37.502533247768746

# %%
np.mean(data)
# Out:
# 46.6

# %%
sum=0
for i in data:
    sum=sum+i
mean=sum(len(data))

(X-mean)**2/n
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 4
#       2 for i in data:
#       3     sum=sum+i
# ----> 4 mean=sum(len(data))
#       6 (X-mean)**2/n
#
# TypeError: 'int' object is not callable

# %%
def var(data):
    
    var=(data-np.mean(data)**2/len(data))
    return var
var(data)
# Out:
# array([-215.156, -185.156, -172.156, -154.156, -128.156, -119.156,
#        -116.156, -215.156, -215.156, -185.156])

# %%
np.var(data)
# Out:
# 1406.44

# %%
statistics.variance(data)#sample variance
# Out:
# 1562.7111111111112

# %%
statistics.pvariance(data)#poulation variance
# Out:
# 1406.44

# %%
import math
math.sqrt(statistics.pvariance(data))
# Out:
# 37.502533247768746

# %%
df=sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.corr()
# Out:
# /tmp/ipykernel_1457/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
#sns.heatmap(df)
df=df[['total_bill','tip','size']]

# %%
df
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
sns.heatmap(df[['total_bill','tip','size']])
# Out:
# <AxesSubplot: >

# %%
corr=df[['total_bill','tip','size']].corr()
sns.heatmap(corr)
# Out:
# <AxesSubplot: >

# %%
df.cov()
# Out:
#             total_bill       tip      size
# total_bill   79.252939  8.323502  5.065983
# tip           8.323502  1.914455  0.643906
# size          5.065983  0.643906  0.904591

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# size          0
# dtype: int64

# %%
sns.pairplot(df)

# %%
sns.scatterplot(x=df['tip'],y=df['size'])
# Out:
# <AxesSubplot: xlabel='tip', ylabel='size'>

# %%
sns.scatterplot(y=df['total_bill'],x=df['size'])
# Out:
# <AxesSubplot: xlabel='size', ylabel='total_bill'>

# %%
#probability density function

# %%
data
# Out:
# [2, 32, 45, 63, 89, 98, 101, 2, 2, 32]

# %%
sns.histplot(data)
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
sns.histplot(data,kde=True)#kreanel density function
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
df
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'size'], dtype='object')

# %%
sns.histplot(df['total_bill'],kde=True)
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='Count'>

# %%
data.append(1000)

# %%
sns.histplot(data,kde=True)
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
#normal distubution

# %%
var=np.random.normal(0.5,0.2,1000)

# %%
sns.histplot(var,kde=True)
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
sns.distplot(var,kde=True)
# Out:
# /tmp/ipykernel_1457/1544059795.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(var,kde=True)
# <AxesSubplot: ylabel='Density'>

# %%
#log normal distribution

# %%
var1=np.random.lognormal(3,2,1000)

# %%
sns.histplot(var1,kde=True)
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
sns.distplot(var1,kde=True)
# Out:
# /tmp/ipykernel_1457/1687382427.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(var1,kde=True)
# <AxesSubplot: ylabel='Density'>

# %%
sns.distplot(np.log(var1),kde=True)
# Out:
# /tmp/ipykernel_1457/401198603.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(var1),kde=True)
# <AxesSubplot: ylabel='Density'>

# %%
#Q-Q plot 
import matplotlib.pyplot as plt 
import scipy.stats as stat
import pylab

# %%
def plot_data(sample):
    plt.figure(figsize = (10, 6))
    plt.subplot(1, 2, 1)
    sns.histplot(sample, kde = True)
    plt.subplot(1, 2, 2)
    stat.probplot(sample, dist = 'norm', plot=pylab)

# %%
plot_data(data)

# %%
var
# Out:
# array([ 0.35200894,  0.59292923,  0.46878775,  0.44127623,  0.42676178,
#         0.52465637,  0.62966712,  0.62996604,  0.32975217,  0.35061482,
#         0.6222123 ,  0.60882095,  0.67744082,  0.26663661,  0.12939312,
#         0.46001759,  0.42743104,  0.48631107,  0.66700234,  0.80988891,
#         0.48252891,  0.8148235 ,  0.63026875,  0.54172195,  0.93323143,
#         0.61428816,  0.40465491,  0.33571871,  0.55385472,  0.92084803,
#         0.37881917,  1.1926451 ,  0.30816478,  0.09287313,  0.78320184,
#         0.71395547,  0.58121046,  0.53974768, -0.01571337,  0.24583495,
#         0.39520614,  0.30428574,  0.58233886,  0.42900414,  0.34055812,
#         0.53090026,  0.50666678,  0.61310487,  0.47696828,  0.12295324,
#         0.45673886,  0.4395455 ,  0.46571974,  0.70287923,  0.58779588,
#         0.47689127,  0.55830327,  0.69585891,  0.66621814,  0.57497629,
#         0.4474411 ,  0.59865868,  0.615153  ,  0.45537159,  0.93737808,
# ...

# %%
plot_data(var)

# %%
var = np.random.lognormal(3, 2, 1000)

# %%
var
# Out:
# array([7.86063959e+00, 6.06909170e+01, 1.30395787e+01, 2.96262311e+01,
#        2.77435022e+00, 6.43018374e+00, 8.94836928e+00, 1.04109538e+01,
#        5.08407531e+01, 6.74123820e+01, 9.69410166e+00, 2.43893318e+01,
#        6.10155088e+01, 2.68975897e+01, 6.18229328e+01, 9.80817321e+01,
#        1.09317026e+00, 2.58811706e+01, 4.75796815e+00, 7.70503912e+01,
#        1.28304942e+01, 3.33103806e+00, 1.64856189e-01, 6.91560522e+01,
#        4.77726882e-01, 7.05614127e+01, 3.48156407e-01, 1.32553424e-01,
#        1.78244392e+00, 4.91583067e+00, 4.26794711e+01, 3.52562741e+02,
#        1.09744417e+01, 3.09529942e+02, 1.52901296e+00, 2.54093015e+01,
#        6.25341535e+01, 2.31486526e+01, 8.14917294e+00, 2.23903293e+02,
#        6.65063951e-01, 1.39037903e+01, 5.96155731e+02, 1.01428195e+02,
#        5.88088078e+01, 4.92332672e+01, 3.58666846e+00, 2.09399544e+02,
#        5.17835105e+00, 5.88082857e+00, 3.72778119e+01, 1.44076346e+02,
# ...

# %%
plot_data(var)

# %%
plot_data(np.log(var))#

# %%
population=np.random.randint(10,20,50)
population
# Out:
# array([17, 16, 10, 13, 18, 14, 10, 16, 17, 11, 18, 14, 16, 17, 13, 16, 13,
#        19, 10, 16, 11, 16, 13, 16, 14, 10, 15, 19, 17, 12, 19, 11, 12, 16,
#        15, 15, 16, 16, 13, 16, 19, 18, 19, 19, 12, 10, 15, 18, 14, 13])

# %%
len(population)
# Out:
# 50

# %%
from statistics import mode
print(f"mean of the population {np.mean(population)}")
print(f"median of the population {np.median(population)}")
print(f"mode of the population {mode(population)}")
# Out:
# mean of the population 14.86
# median of the population 15.5
# mode of the population 16

# %%
sample=np.random.choice(population,20)
print(f"mean of the population {np.mean(sample)}")
print(f"median of the population {np.median(sample)}")
print(f"mode of the population {mode(sample)}")
# Out:
# mean of the population 15.45
# median of the population 15.5
# mode of the population 19

# %%
sample1=np.random.choice(population,20)
sample2=np.random.choice(population,20)
sample3=np.random.choice(population,20)
sample4=np.random.choice(population,20)

# %%
print(sample)
# Out:
# [13 13 18 18 18 10 15 16 10 12 19 12 16 15 10 12 16 18 14 19]

# %%
mean_of_sample=[]
all_sample=[sample1,sample2,sample3,sample4]
for sample in all_sample:
    mean_of_sample.append(np.mean(sample))

# %%
mean_of_sample
# Out:
# [14.8, 14.65, 15.95, 15.55]

# %%
#central limit theorem
population=np.random.binomial(10,0.5,10000)
population
# Out:
# array([7, 3, 6, ..., 2, 2, 3])

# %%
len(population)
# Out:
# 10000

# %%
sns.distplot(population)
# Out:
# /tmp/ipykernel_86/2958836585.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(population)
# <AxesSubplot: ylabel='Density'>

# %%
population
# Out:
# array([6, 5, 5, ..., 6, 5, 6])

# %%
size = int(len(population)*0.30)

# %%
size
# Out:
# 3000

# %%
mean_of_samples = []


for i in range(1,31):
    sample = np.random.choice(population, size = size)
    mean_of_samples.append(np.mean(sample))

# %%
mean_of_samples
# Out:
# [4.952333333333334,
#  4.953,
#  5.012,
#  5.042,
#  5.050666666666666,
#  5.030666666666667,
#  4.958333333333333,
#  5.020666666666667,
#  5.016,
#  4.995,
#  5.021,
#  4.969666666666667,
#  5.02,
#  4.9976666666666665,
#  5.004666666666667,
#  5.022,
#  4.980333333333333,
#  4.9943333333333335,
#  4.979,
#  5.01,
#  4.9976666666666665,
#  5.0,
#  4.983,
#  5.025666666666667,
#  4.956333333333333,
#  5.036666666666667,
#  5.011666666666667,
#  5.036666666666667,
#  4.970666666666666,
#  4.977]

# %%
len(mean_of_samples)
# Out:
# 30

# %%
sns.distplot(mean_of_samples,kde=True)
# Out:
# /tmp/ipykernel_86/122225809.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(mean_of_samples,kde=True)
# <AxesSubplot: ylabel='Density'>

# %%
mean_of_samples = []


for i in range(1,100):
    sample = np.random.choice(population, size = size)
    mean_of_samples.append(np.mean(sample))

# %%
sns.distplot(mean_of_samples,kde=True)
# Out:
# /tmp/ipykernel_86/122225809.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(mean_of_samples,kde=True)
# <AxesSubplot: ylabel='Density'>

# %%
mean_of_samples = []


for i in range(1,500):
    sample = np.random.choice(population, size = size)
    mean_of_samples.append(np.mean(sample))

# %%
sns.distplot(mean_of_samples,kde=True)
# Out:
# /tmp/ipykernel_86/122225809.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(mean_of_samples,kde=True)
# <AxesSubplot: ylabel='Density'>

# %%
mean_of_samples = []


for i in range(1,800):
    sample = np.random.choice(population, size = size)
    mean_of_samples.append(np.mean(sample))

# %%
sns.distplot(mean_of_samples,kde=True)
# Out:
# /tmp/ipykernel_86/122225809.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(mean_of_samples,kde=True)
# <AxesSubplot: ylabel='Density'>

# %%
import scipy.stats as stats

# %%
stats.norm.ppf(q=0.95)
# Out:
# 1.6448536269514722

# %%
stats.t.ppf(q=0.97,df=24)
# Out:
# 1.973994288847133

# %%
population = np.random.randint(10, 20, 50)
population
# Out:
# array([16, 13, 12, 12, 10, 12, 17, 11, 18, 12, 10, 19, 17, 17, 16, 11, 12,
#        12, 11, 19, 11, 14, 11, 16, 11, 12, 19, 16, 11, 15, 10, 16, 10, 14,
#        17, 19, 10, 12, 14, 19, 16, 18, 14, 10, 16, 11, 16, 14, 10, 19])

# %%
sample1 = np.random.choice(population, 20)
sample2 = np.random.choice(population, 20)
sample3 = np.random.choice(population, 20)
sample4 = np.random.choice(population, 20)

# %%
mean_of_samples = []
all_sample = [sample1, sample2, sample3, sample4]

for sample in all_sample:
    mean_of_samples.append(np.mean(sample))

# %%
z_critical=stats.norm.ppf(q=0.975)
z_critical
# Out:
# 1.959963984540054

# %%
mean_of_samples
# Out:
# [13.55, 13.25, 14.1, 14.3]

# %%
margin_of_error=z_critical*np.std(mean_of_sample)/np.sqrt(20)#margin of error

# %%
margin_of_error
# Out:
# 0.23415982231373772

# %%
np.mean(mean_of_samples)-margin_of_error,np.mean(mean_of_samples)+margin_of_error #confidance interval
# Out:
# (13.565840177686264, 14.034159822313738)

# %%
#Z test
from numpy.random import randn
population=randn(100)
population
# Out:
# array([ 9.06518228e-01,  1.40948380e-01, -1.09414538e-01, -6.85414285e-01,
#         4.28409234e-01, -9.90696039e-01, -6.40801229e-01, -1.60555332e+00,
#         1.04907942e+00,  1.26670192e+00,  2.65508162e-01,  5.39751707e-01,
#         1.52666464e+00, -4.72728655e-01, -1.13940630e+00, -2.58697557e-01,
#         6.74775120e-01,  2.18598452e+00, -4.21361183e-01, -2.75461988e-02,
#         1.64851518e+00, -1.74225706e+00, -6.62290946e-02, -1.04658898e+00,
#         7.24554165e-01,  2.45075873e-01,  1.95451594e-01,  6.36094978e-01,
#        -7.21322330e-01,  7.98907433e-01, -2.54711643e-03, -1.77391529e+00,
#         5.33034667e-01,  1.21831325e+00,  8.64590757e-01,  1.34281216e+00,
#         1.66748572e+00,  1.14841443e-01, -1.58252517e+00, -1.39680287e+00,
#         7.90729640e-01, -1.17789256e+00,  3.56711084e-01,  8.69888202e-01,
#        -7.72096724e-02,  7.75880882e-01, -1.90887795e+00,  6.79052976e-01,
# ...

# %%
sns.distplot(population)
# Out:
# /tmp/ipykernel_86/2958836585.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(population)
# <AxesSubplot: ylabel='Density'>

# %%
np.mean(population),np.std(population)
# Out:
# (0.008078138541556217, 0.976234545375691)

# %%
null_mean=0.008
#pvalue <=0.05 ----- reject h0
#pvalue>0.05------fail to rejectc null hypothesis

# %%
from statsmodels.stats.weightstats import ztest

# %%
zscore,pvalue=ztest(population,value=null_mean,alternative='larger' )

# %%
pvalue
# Out:
# 0.5432621780666432

# %% [markdown]
# we fail to reject null hypothesis, that is we acppect null hypo

# %%
if(pvalue<0.05):
    print('reject yhe null hypothesis')
else:
    print('fail to reject null hypothesis')
# Out:
# fail to reject null hypothesis

# %%
### how to know if a given data is following normal distribution or not
##distributon plot ,q-q plot 
##statistical test

# %%
data = pd.read_csv("https://raw.githubusercontent.com/shrikant-temburwar/Wine-Quality-Dataset/master/winequality-red.csv", sep = ";")

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
from numpy.random import randn
population=randn(1000)
population
# Out:
# array([-3.74969893e-01,  5.41757304e-01,  7.39953603e-01,  1.97997504e-01,
#         1.02520666e+00, -7.91561337e-01, -9.23040174e-01,  1.53689420e+00,
#        -2.04695985e+00, -8.84446594e-01, -5.31246818e-01,  7.06692067e-01,
#         1.08402256e+00, -6.46996436e-03,  4.31888656e-01,  1.90013141e-01,
#         5.60327405e-01, -5.59381983e-01,  1.17350052e+00,  1.37463233e-01,
#        -1.15569316e+00,  3.47149732e-01, -5.56579175e-01, -4.57776626e-01,
#         5.55052049e-01, -6.16133349e-01, -3.17870837e-01, -5.14509869e-01,
#        -8.19086836e-02,  4.31768781e-01,  2.33988042e-01, -4.54068321e-02,
#         6.11602776e-01,  2.33577167e-01, -5.04945362e-01,  2.34367228e-01,
#        -2.63744676e+00, -9.93018047e-01, -2.12012195e+00, -4.78837522e-01,
#        -2.15342715e+00, -9.25489243e-01, -1.93653075e-01, -3.75674533e-01,
#        -9.20973615e-01,  1.08852313e+00,  1.15238445e+00, -5.92548360e-02,
# ...

# %%
sns.distplot(population)
# Out:
# /tmp/ipykernel_86/2958836585.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(population)
# <AxesSubplot: ylabel='Density'>

# %%
from scipy import stats
stats.shapiro(population)
# Out:
# ShapiroResult(statistic=0.9980661273002625, pvalue=0.3114446699619293)

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
sns.distplot(data['fixed acidity'])
# Out:
# /tmp/ipykernel_86/1541798658.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['fixed acidity'])
# <AxesSubplot: xlabel='fixed acidity', ylabel='Density'>

# %%
data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
sns.distplot(data['volatile acidity'])
# Out:
# /tmp/ipykernel_86/741555854.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['volatile acidity'])
# <AxesSubplot: xlabel='volatile acidity', ylabel='Density'>

# %%
stats.shapiro(data['volatile acidity'])# reject ho ,not normally disttributon
# Out:
# ShapiroResult(statistic=0.9743338823318481, pvalue=2.686385373947307e-16)

# %%
stats.shapiro(data['fixed acidity'])
# Out:
# ShapiroResult(statistic=0.9420264959335327, pvalue=1.5227779442162196e-24)

# %%
#t test >>  ss<30 sigma pop given

# %%
# one-sample t test(with respect to one independent sample)
# two-sample t test(with respect to two independent sample)
# paired t-test(two sample from the sample population on different time interval)

# %%
#one sample t test
population=np.random.randint(10,50,50)
population
# Out:
# array([49, 15, 33, 34, 29, 25, 46, 44, 34, 20, 36, 40, 17, 24, 10, 11, 12,
#        48, 25, 11, 30, 39, 20, 23, 28, 44, 27, 13, 47, 20, 27, 21, 15, 46,
#        41, 11, 37, 36, 24, 27, 26, 42, 37, 47, 31, 17, 42, 24, 36, 47])

# %%
my_score=np.random.choice(population,20)
my_score
# Out:
# array([11, 27, 15, 13, 41, 44, 39, 24, 36, 24, 20, 10, 47, 46, 47, 47, 36,
#        47, 47, 48])

# %%
np.mean(my_score)
# Out:
# 33.45

# %%
import scipy
scipy.stats.ttest_1samp(my_score,10)
# Out:
# Ttest_1sampResult(statistic=7.5019660583995025, pvalue=4.295361711239582e-07)

# %%
#two sample t test

# %%
my_score
# Out:
# array([11, 27, 15, 13, 41, 44, 39, 24, 36, 24, 20, 10, 47, 46, 47, 47, 36,
#        47, 47, 48])

# %%
#rohit_score=np.random.choice(population,20)
rohit_score=[48, 62,15, 31, 27, 47, 67, 17, 27, 20, 42,68,36,45,15, 34, 25, 34, 15, 30, 31, 44,
       48, 89, 20]

# %%
rohit_score
# Out:
# [48,
#  62,
#  15,
#  31,
#  27,
#  47,
#  67,
#  17,
#  27,
#  20,
#  42,
#  68,
#  36,
#  45,
#  15,
#  34,
#  25,
#  34,
#  15,
#  30,
#  31,
#  44,
#  48,
#  89,
#  20]

# %%
np.mean(rohit_score),np.mean(my_score)
# Out:
# (37.48, 33.45)

# %%
scipy.stats.ttest_ind(my_score,rohit_score)
# Out:
# Ttest_indResult(statistic=-0.7945496727839392, pvalue=0.43123910123035847)

# %%
#paired t test >> two sample population at different time interval is taken

# %%
rohit_score_frist_inning=[31, 36, 46, 24, 48, 46, 47, 47, 16, 35, 45, 37, 24, 29, 27, 42, 49, 37, 47, 46]
rohit_score_second_inning=[32, 36, 46, 24, 20, 46, 47, 46, 63, 35, 45, 37, 24, 29, 30, 42, 49, 57, 47, 46]

# %%
np.mean(rohit_score_frist_inning)
# Out:
# 37.95

# %%
np.mean(rohit_score_second_inning)
# Out:
# 40.05

# %%
scipy.stats.ttest_ind(rohit_score_frist_inning,rohit_score_second_inning)
# Out:
# Ttest_indResult(statistic=-0.6257405248722444, pvalue=0.5352256163887427)

# %%
#chiSqaure test

# %%
data=sns.load_dataset('tips')
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
data[["sex","smoker"]]
# Out:
#         sex smoker
# 0    Female     No
# 1      Male     No
# 2      Male     No
# 3      Male     No
# 4    Female     No
# ..      ...    ...
# 239    Male     No
# 240  Female    Yes
# 241    Male    Yes
# 242    Male     No
# 243  Female     No
#
# [244 rows x 2 columns]

# %%
data_table=pd.crosstab(data['sex'],data['smoker'])
data_table
# Out:
# smoker  Yes  No
# sex
# Male     60  97
# Female   33  54

# %%
observed_values=data_table.values
observed_values
# Out:
# array([[60, 97],
#        [33, 54]])

# %%
import scipy.stats as stats

# %%
stats_test,p,dof,Expected_Values=stats.chi2_contingency(observed_values)

# %%
Expected_Values
# Out:
# array([[59.84016393, 97.15983607],
#        [33.15983607, 53.84016393]])

# %%
no_of_rows=data_table.iloc[0:2,0]
no_of_rows
# Out:
# sex
# Male      60
# Female    33
# Name: Yes, dtype: int64

# %%
no_of_columns=data_table.iloc[0,0:2]
no_of_columns
# Out:
# smoker
# Yes    60
# No     97
# Name: Male, dtype: int64

# %%
dof=(len(no_of_columns)-1)*(len(no_of_rows)-1)

# %%
dof
# Out:
# 1

# %%
observed_values
# Out:
# array([[60, 97],
#        [33, 54]])

# %%
Expected_Values
# Out:
# array([[59.84016393, 97.15983607],
#        [33.15983607, 53.84016393]])

# %%
for o,e in zip(observed_values,Expected_Values):
    print(o,e)
# Out:
# [60 97] [59.84016393 97.15983607]
# [33 54] [33.15983607 53.84016393]

# %%
from scipy.stats import chi2
chisqure_test=sum([(o-e)**2./e for o,e in zip(observed_values,Expected_Values)])

# %%
chisqure_test
# Out:
# array([0.00119737, 0.00073745])

# %%
chi_square_statistic=chisqure_test[0]+chisqure_test[1]

# %%
chi_square_statistic
# Out:
# 0.001934818536627623

# %%
dof
# Out:
# 1

# %%
alpha=0.05

# %%
from scipy.stats import chi2

# %%
critical_value=chi2.ppf(1-alpha,df=dof)

# %%
critical_value
# Out:
# 3.841458820694124

# %%
if chi_square_statistic>=critical_value:
    print("Reject H0,There is a relationship between 2 categorical variables")
else:
    print("Retain H0,There is no relationship between 2 categorical variables")
# Out:
# Retain H0,There is no relationship between 2 categorical variables

# %%
#p-value
p_value=1-chi2.cdf(x=chi_square_statistic,df=dof)

# %%
if p_value<=alpha:
    print("Reject H0,There is a relationship between 2 categorical variables")
else:
    print("Retain H0,There is no relationship between 2 categorical variables")
# Out:
# Retain H0,There is no relationship between 2 categorical variables
